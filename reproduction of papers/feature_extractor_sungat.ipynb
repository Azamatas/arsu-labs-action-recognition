# %%
import os
import pandas as pd
import numpy as np

# os.chdir(r"C:\Users\attou\OneDrive\Desktop\ExtraSensory Brut")


# Features to extract
def extract_features(df, start, end):
    window = df[start:end]

    stats = {
        "mean": window.mean(),
        "std": window.std(),
        "min": window.min(),
        "max": window.max(),
        "median": window.median(),
        "iqr": window.quantile(0.75) - window.quantile(0.25),
        "range": window.max() - window.min(),
        "mad": window.apply(lambda x: (x - x.mean()).abs().mean()),
        "skew": window.skew(),
        "kurtosis": window.kurtosis(),
        "energy": (window**2).sum(),
        "rms": (window**2).mean().pow(0.5),
        "variance": window.var(),
        "max_latency": window.idxmax(),
        "min_latency": window.idxmin(),
        "third_moment": window.apply(lambda x: ((x - x.mean()) ** 3).mean()),
        "fourth_moment": window.apply(lambda x: ((x - x.mean()) ** 4).mean()),
        "mean_abs_first_diff": window.apply(lambda x: x.diff().abs().mean()),
        "mean_abs_second_diff": window.apply(lambda x: x.diff().diff().abs().mean()),
        "percentile_25": window.quantile(0.25),
        "percentile_75": window.quantile(0.75),
        "value_entropy": window.apply(
            lambda x: (
                -sum(p * np.log2(p) for p in x.value_counts(normalize=True) if p > 0)
            )
        ),
    }

    features = pd.concat(stats.values(), axis=0).to_frame().T
    features.columns = [f"{stat}_{col}" for stat in stats for col in window.columns]
    return features


# Extract files names
folder = r"./data/raw_acc"
dirs = [d for d in os.listdir(folder) if os.path.isdir(os.path.join(folder, d))]

# %% [markdown]
# # Windows size of 20 s

# %%
window_size = 40 * 20  # 40hz * 20s

# %%
for user in dirs:
    print(user)
    ###############################################
    path = os.path.join(folder, user)
    file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    all_dfs = []

    for file in file_names:
        df = pd.read_csv(os.path.join(path, file), sep=" ", header=None)
        df.drop(0, axis=1, inplace=True)
        df.columns = ["X", "Y", "Z"]

        file_dfs = []
        for start in range(0, len(df) - window_size + 1, window_size):
            end = start + window_size
            features = extract_features(df, start, end)
            file_dfs.append(features)

        df_features = pd.concat(file_dfs, ignore_index=True)
        df_features["timestamp"] = file.split(".")[0]
        all_dfs.append(df_features)

    data_ACC = pd.concat(all_dfs, ignore_index=True)
    print(data_ACC.shape)
    ###############################################
    ################################################

    path = os.path.join("./data/audio_naive", user)
    file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    all_features = []
    all_timestamps = []

    for file in file_names:
        file_path = os.path.join(path, file)
        df = pd.read_csv(file_path, header=None)
        df.dropna(axis=1, inplace=True)

        X = df.values  # shape: (n_frames, 13)

        # Statistiques : mean, std, min, max
        stats = [X.mean(axis=0), X.std(axis=0), X.min(axis=0), X.max(axis=0)]
        features = np.concatenate(stats)

        all_features.append(features)
        all_timestamps.append(file.split(".")[0])

    # Création des noms de colonnes
    columns = []
    for stat in ["mean", "std", "min", "max"]:
        columns += [f"mfcc{i}_{stat}" for i in range(X.shape[1])]

    # Création du DataFrame
    data_audio = pd.DataFrame(all_features, columns=columns)
    data_audio["timestamp"] = all_timestamps
    print(data_audio.shape)
    ##############################################################################

    location_path = r"./data/ExtraSensory.per_uuid_absolute_location"
    filename = user + ".absolute_locations.csv.gz"

    full_path = os.path.join(location_path, filename)

    data_loc = pd.read_csv(full_path, compression="gzip")

    print(data_loc.shape)
    ##############################################################################

    location_path = r"./data/ExtraSensory.per_uuid_original_labels"
    filename = user + ".original_labels.csv.gz"
    full_path = os.path.join(location_path, filename)

    data_label = pd.read_csv(full_path, compression="gzip")
    cols_to_drop = [col for col in data_label.columns if "PHONE" in col.upper()]
    data_label = data_label.drop(columns=cols_to_drop)
    data_label.columns = data_label.columns.str.replace(
        "^original_label:", "", regex=True
    )
    data_label.drop("label_source", axis=1, inplace=True)
    print(data_label.shape)

    ####################################################################################
    ####################################################################################
    ####################################FUSION##########################################
    data_merged = pd.merge(data_ACC, data_audio, on="timestamp", how="left")

    data_merged["timestamp"] = data_merged["timestamp"].astype(int)
    data_loc["timestamp"] = data_loc["timestamp"].astype(int)
    data_final = pd.merge(data_merged, data_loc, on="timestamp", how="left")

    data_final_2 = pd.merge(data_final, data_label, on="timestamp", how="left")

    output_folder = "20s"
    os.makedirs(output_folder, exist_ok=True)
    output_path = os.path.join(output_folder, f"{user}__20s.csv")
    
    data_final_2.to_csv(output_path, index=False)
    ##################################################################################
    print("*" * 80)
# Out:
# 1155FF54-63D3-4AB2-9863-8385D0BD0A13
# (2685, 67)
# (2674, 53)
# (2685, 3)
# (2685, 105)
# ********************************************************************************
# 1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842
# (7371, 67)
# (7366, 53)
# (7375, 3)
# (7375, 105)
# ********************************************************************************
# 797D145F-3858-4A7F-A7C2-A4EB721E133C
# (3593, 67)
# (3588, 53)
# (3593, 3)
# (3593, 105)
# ********************************************************************************
# C48CE857-A0DD-4DDB-BEA5-3A25449B2153
# (5091, 67)
# (4984, 53)
# (5092, 3)
# (5092, 105)
# ********************************************************************************
# 098A72A5-E3E5-4F54-A152-BBDA0DF7B694
# (6808, 67)
# (6735, 53)
# (6813, 3)
# (6813, 105)
# ********************************************************************************
# 0A986513-7828-4D53-AA1F-E02D6DF9561B
# (3960, 67)
# (3956, 53)
# (3960, 3)
# (3960, 105)
# ********************************************************************************
# E65577C1-8D5D-4F70-AF23-B3ADB9D3DBA3
# (3441, 67)
# (3399, 53)
# (3441, 3)
# (3441, 105)
# ********************************************************************************
# 86A4F379-B305-473D-9D83-FC7D800180EF
# (10716, 67)
# (10699, 53)
# (10738, 3)
# (10738, 105)
# ********************************************************************************
# 78A91A4E-4A51-4065-BDA7-94755F0BB3BB
# (11996, 67)
# (11865, 53)
# (11996, 3)
# (11996, 105)
# ********************************************************************************
# 5EF64122-B513-46AE-BCF1-E62AAC285D2C
# (3911, 67)
# (3851, 53)
# (3911, 3)
# (3911, 105)
# ********************************************************************************
# 40E170A7-607B-4578-AF04-F021C3B0384A
# (7648, 67)
# (7626, 53)
# (7649, 3)
# (7649, 105)
# ********************************************************************************
# 81536B0A-8DBF-4D8A-AC24-9543E2E4C8E0
# (6343, 67)
# (6253, 53)
# (6407, 3)
# (6407, 105)
# ********************************************************************************
# 5152A2DF-FAF3-4BA8-9CA9-E66B32671A53
# (6617, 67)
# (6459, 53)
# (6617, 3)
# (6617, 105)
# ********************************************************************************
# 4E98F91F-4654-42EF-B908-A3389443F2E7
# (3244, 67)
# (3238, 53)
# (3250, 3)
# (3250, 105)
# ********************************************************************************
# CDA3BBF7-6631-45E8-85BA-EEB416B32A3C
# (2860, 67)
# (2765, 53)
# (2860, 3)
# (2860, 105)
# ********************************************************************************
# 61359772-D8D8-480D-B623-7C636EAD0C81
# (6072, 67)
# (6071, 53)
# (6079, 3)
# (6079, 105)
# ********************************************************************************
# 481F4DD2-7689-43B9-A2AA-C8772227162B
# (6690, 67)
# (6679, 53)
# (6691, 3)
# (6691, 105)
# ********************************************************************************
# 136562B6-95B2-483D-88DC-065F28409FD2
# (6218, 67)
# (5853, 53)
# (6218, 3)
# (6218, 105)
# ********************************************************************************
# 8023FE1A-D3B0-4E2C-A57A-9321B7FC755F
# (9189, 67)
# (9065, 53)
# (9189, 3)
# (9189, 105)
# ********************************************************************************
# 83CF687B-7CEC-434B-9FE8-00C3D5799BE6
# (9539, 67)
# (9375, 53)
# (9539, 3)
# (9539, 105)
# ********************************************************************************
# FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF
# (4973, 67)
# (4949, 53)
# (4973, 3)
# (4973, 105)
# ********************************************************************************
# 59818CD2-24D7-4D32-B133-24C2FE3801E5
# (5946, 67)
# (5946, 53)
# (5947, 3)
# (5947, 105)
# ********************************************************************************
# 96A358A0-FFF2-4239-B93E-C7425B901B47
# (5811, 67)
# (5403, 53)
# (5819, 3)
# (5819, 105)
# ********************************************************************************
# 7CE37510-56D0-4120-A1CF-0E23351428D2
# (9760, 67)
# (9698, 53)
# (9761, 3)
# (9761, 105)
# ********************************************************************************
# 3600D531-0C55-44A7-AE95-A7A38519464E
# (5203, 67)
# (5131, 53)
# (5203, 3)
# (5203, 105)
# ********************************************************************************
# ECECC2AB-D32F-4F90-B74C-E12A1C69BBE2
# (3530, 67)
# (92, 53)
# (3530, 3)
# (3530, 105)
# ********************************************************************************
# 61976C24-1C50-4355-9C49-AAE44A7D09F6
# (8730, 67)
# (7696, 53)
# (8730, 3)
# (8730, 105)
# ********************************************************************************
# A7599A50-24AE-46A6-8EA6-2576F1011D81
# (3898, 67)
# (3897, 53)
# (3898, 3)
# (3898, 105)
# ********************************************************************************
# 74B86067-5D4B-43CF-82CF-341B76BEA0F4
# (7267, 67)
# (7267, 53)
# (7298, 3)
# (7298, 105)
# ********************************************************************************
# 1538C99F-BA1E-4EFB-A949-6C7C47701B20
# (6549, 67)
# (6470, 53)
# (6549, 3)
# (6549, 105)
# ********************************************************************************
# BE3CA5A6-A561-4BBD-B7C9-5DF6805400FC
# (8309, 67)
# (8254, 53)
# (8309, 3)
# (8309, 105)
# ********************************************************************************
# 24E40C4C-A349-4F9F-93AB-01D00FB994AF
# (4771, 67)
# (4481, 53)
# (4771, 3)
# (4771, 105)
# ********************************************************************************
# F50235E0-DD67-4F2A-B00B-1F31ADA998B9
# (2259, 67)
# (2259, 53)
# (2266, 3)
# (2266, 105)
# ********************************************************************************
# CF722AA9-2533-4E51-9FEB-9EAC84EE9AAC
# (3615, 67)
# (3610, 53)
# (3615, 3)
# (3615, 105)
# ********************************************************************************
# D7D20E2E-FC78-405D-B346-DBD3FD8FC92B
# (6210, 67)
# (6034, 53)
# (6210, 3)
# (6210, 105)
# ********************************************************************************
# A5CDF89D-02A2-4EC1-89F8-F534FDABDD96
# (6040, 67)
# (5948, 53)
# (6040, 3)
# (6040, 105)
# ********************************************************************************
# 99B204C0-DD5C-4BB7-83E8-A37281B8D769
# (6028, 67)
# (6025, 53)
# (6038, 3)
# (6038, 105)
# ********************************************************************************
# CA820D43-E5E2-42EF-9798-BE56F776370B
# (7864, 67)
# (7635, 53)
# (7865, 3)
# (7865, 105)
# ********************************************************************************
# 0BFC35E2-4817-4865-BFA7-764742302A2D
# (3090, 67)
# (3086, 53)
# (3108, 3)
# (3108, 105)
# ********************************************************************************
# 33A85C34-CFE4-4732-9E73-0A7AC861B27A
# (6164, 67)
# (6160, 53)
# (6172, 3)
# (6172, 105)
# ********************************************************************************
# 2C32C23E-E30C-498A-8DD2-0EFB9150A02E
# (8516, 67)
# (8120, 53)
# (8516, 3)
# (8516, 105)
# ********************************************************************************
# B9724848-C7E2-45F4-9B3F-A1F38D864495
# (7626, 67)
# (7483, 53)
# (7626, 3)
# (7626, 105)
# ********************************************************************************
# 9DC38D04-E82E-4F29-AB52-B476535226F2
# (9686, 67)
# (9277, 53)
# (9686, 3)
# (9686, 105)
# ********************************************************************************
# 11B5EC4D-4133-4289-B475-4E737182A406
# (8845, 67)
# (8834, 53)
# (8845, 3)
# (8845, 105)
# ********************************************************************************
# 5119D0F8-FCA8-4184-A4EB-19421A40DE0D
# (6617, 67)
# (6557, 53)
# (6617, 3)
# (6617, 105)
# ********************************************************************************
# 27E04243-B138-4F40-A164-F40B60165CF3
# (4925, 67)
# (4811, 53)
# (4927, 3)
# (4927, 105)
# ********************************************************************************
# A76A5AF5-5A93-4CF2-A16E-62353BB70E8A
# (7520, 67)
# (7417, 53)
# (7520, 3)
# (7520, 105)
# ********************************************************************************
# 00EABED2-271D-49D8-B599-1D4A09240601
# (2287, 67)
# (2228, 53)
# (2287, 3)
# (2287, 105)
# ********************************************************************************
# 9759096F-1119-4E19-A0AD-6F16989C7E1C
# (9959, 67)
# (9889, 53)
# (9959, 3)
# (9959, 105)
# ********************************************************************************
# 7D9BB102-A612-4E2A-8E22-3159752F55D8
# (1600, 67)
# (1598, 53)
# (1600, 3)
# (1600, 105)
# ********************************************************************************
# B7F9D634-263E-4A97-87F9-6FFB4DDCB36C
# (9383, 67)
# (9383, 53)
# (9383, 3)
# (9383, 105)
# ********************************************************************************
# BEF6C611-50DA-4971-A040-87FB979F3FC1
# (3450, 67)
# (3448, 53)
# (3451, 3)
# (3451, 105)
# ********************************************************************************
# 4FC32141-E888-4BFF-8804-12559A491D8C
# (4979, 67)
# (4883, 53)
# (4979, 3)
# (4979, 105)
# ********************************************************************************
# 59EEFAE0-DEB0-4FFF-9250-54D2A03D0CF2
# (7537, 67)
# (7413, 53)
# (7542, 3)
# (7542, 105)
# ********************************************************************************
# CCAF77F0-FABB-4F2F-9E24-D56AD0C5A82F
# (8395, 67)
# (8294, 53)
# (8472, 3)
# (8472, 105)
# ********************************************************************************
# 665514DE-49DC-421F-8DCB-145D0B2609AD
# (9166, 67)
# (9157, 53)
# (9167, 3)
# (9167, 105)
# ********************************************************************************
# A5A30F76-581E-4757-97A2-957553A2C6AA
# (1667, 67)
# (1666, 53)
# (1667, 3)
# (1667, 105)
# ********************************************************************************
# B09E373F-8A54-44C8-895B-0039390B859F
# (8134, 67)
# (8005, 53)
# (8134, 3)
# (8134, 105)
# ********************************************************************************
# 806289BC-AD52-4CC1-806C-0CDB14D65EB6
# (9242, 67)
# (9232, 53)
# (9242, 3)
# (9242, 105)
# ********************************************************************************
# 0E6184E1-90C0-48EE-B25A-F1ECB7B9714E
# (7513, 67)
# (7510, 53)
# (7521, 3)
# (7521, 105)
# ********************************************************************************

# %% [markdown]
# # Windows size of 10s

# %%
window_size = 40 * 10

# %%
for user in dirs:
    print(user)
    ###############################################
    path = os.path.join(folder, user)
    file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    all_dfs = []

    for file in file_names:
        df = pd.read_csv(os.path.join(path, file), sep=" ", header=None)
        df.drop(0, axis=1, inplace=True)
        df.columns = ["X", "Y", "Z"]

        file_dfs = []
        for start in range(0, len(df) - window_size + 1, window_size):
            end = start + window_size
            features = extract_features(df, start, end)
            file_dfs.append(features)

        df_features = pd.concat(file_dfs, ignore_index=True)
        df_features["timestamp"] = file.split(".")[0]
        all_dfs.append(df_features)

    data_ACC = pd.concat(all_dfs, ignore_index=True)
    print(data_ACC.shape)
    ###############################################
    ################################################

    path = os.path.join("./data/audio_naive", user)
    file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    all_features = []
    all_timestamps = []

    for file in file_names:
        file_path = os.path.join(path, file)
        df = pd.read_csv(file_path, header=None)
        df.dropna(axis=1, inplace=True)

        X = df.values  # shape: (n_frames, 13)

        # Statistiques : mean, std, min, max
        stats = [X.mean(axis=0), X.std(axis=0), X.min(axis=0), X.max(axis=0)]
        features = np.concatenate(stats)

        all_features.append(features)
        all_timestamps.append(file.split(".")[0])

    # Création des noms de colonnes
    columns = []
    for stat in ["mean", "std", "min", "max"]:
        columns += [f"mfcc{i}_{stat}" for i in range(X.shape[1])]

    # Création du DataFrame
    data_audio = pd.DataFrame(all_features, columns=columns)
    data_audio["timestamp"] = all_timestamps
    print(data_audio.shape)
    ##############################################################################

    location_path = r"./data/ExtraSensory.per_uuid_absolute_location"
    filename = user + ".absolute_locations.csv.gz"

    full_path = os.path.join(location_path, filename)

    data_loc = pd.read_csv(full_path, compression="gzip")

    print(data_loc.shape)
    ##############################################################################

    location_path = r"./data/ExtraSensory.per_uuid_original_labels"
    filename = user + ".original_labels.csv.gz"
    full_path = os.path.join(location_path, filename)

    data_label = pd.read_csv(full_path, compression="gzip")
    cols_to_drop = [col for col in data_label.columns if "PHONE" in col.upper()]
    data_label = data_label.drop(columns=cols_to_drop)
    data_label.columns = data_label.columns.str.replace(
        "^original_label:", "", regex=True
    )
    data_label.drop("label_source", axis=1, inplace=True)
    print(data_label.shape)

    ####################################################################################
    ####################################################################################
    ####################################FUSION##########################################
    data_merged = pd.merge(data_ACC, data_audio, on="timestamp", how="left")

    data_merged["timestamp"] = data_merged["timestamp"].astype(int)
    data_loc["timestamp"] = data_loc["timestamp"].astype(int)
    data_final = pd.merge(data_merged, data_loc, on="timestamp", how="left")

    data_final_2 = pd.merge(data_final, data_label, on="timestamp", how="left")

    output_folder = "10s"
    os.makedirs(output_folder, exist_ok=True)
    output_path = os.path.join(output_folder, f"{user}__10s.csv")
    
    data_final_2.to_csv(output_path, index=False)
    ##################################################################################
    print("*" * 80)
# Out:
# 1155FF54-63D3-4AB2-9863-8385D0BD0A13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 17
#      15 for start in range(0, len(df) - window_size + 1, window_size):
#      16     end = start + window_size
# ---> 17     features = extract_features(df, start, end)
#      18     file_dfs.append(features)
#      20 df_features = pd.concat(file_dfs, ignore_index=True)
#
# Cell In[1], line 17, in extract_features(df, start, end)
#       9 def extract_features(df, start, end):
#      10     window = df[start:end]
#      12     stats = {
#      13         "mean": window.mean(),
#      14         "std": window.std(),
#      15         "min": window.min(),
#      16         "max": window.max(),
# ---> 17         "median": window.median(),
#      18         "iqr": window.quantile(0.75) - window.quantile(0.25),
#      19         "range": window.max() - window.min(),
#      20         "mad": window.apply(lambda x: (x - x.mean()).abs().mean()),
#      21         "skew": window.skew(),
#      22         "kurtosis": window.kurtosis(),
#      23         "energy": (window**2).sum(),
#      24         "rms": (window**2).mean().pow(0.5),
#      25         "variance": window.var(),
#      26         "max_latency": window.idxmax(),
#      27         "min_latency": window.idxmin(),
#      28         "third_moment": window.apply(lambda x: ((x - x.mean()) ** 3).mean()),
#      29         "fourth_moment": window.apply(lambda x: ((x - x.mean()) ** 4).mean()),
#      30         "mean_abs_first_diff": window.apply(lambda x: x.diff().abs().mean()),
#      31         "mean_abs_second_diff": window.apply(lambda x: x.diff().diff().abs().mean()),
#      32         "percentile_25": window.quantile(0.25),
#      33         "percentile_75": window.quantile(0.75),
#      34         "value_entropy": window.apply(
#      35             lambda x: (
#      36                 -sum(p * np.log2(p) for p in x.value_counts(normalize=True) if p > 0)
#      37             )
#      38         ),
#      39     }
#      41     features = pd.concat(stats.values(), axis=0).to_frame().T
#      42     features.columns = [f"{stat}_{col}" for stat in stats for col in window.columns]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:14582, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   14499 @deprecate_nonkeyword_arguments(
#   14500     Pandas4Warning, allowed_args=["self"], name="median"
#   14501 )
#    (...)  14507     **kwargs,
#   14508 ) -> Series | Any:
#   14509     """
#   14510     Return the median of the values over the requested axis.
#   14511
#    (...)  14580     dtype: float64
#   14581     """
# > 14582     result = super().median(
#   14583         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14584     )
#   14585     if isinstance(result, Series):
#   14586         result = result.__finalize__(self, method="median")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:11843, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11835 def median(
#   11836     self,
#   11837     *,
#    (...)  11841     **kwargs,
#   11842 ) -> Series | float:
# > 11843     return self._stat_function(
#   11844         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11845     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:13617, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13613     df = df.T
#   13615 # After possibly _get_data and transposing, we are now in the
#   13616 #  simple case where we can use BlockManager.reduce
# > 13617 res = df._mgr.reduce(blk_func)
#   13618 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13619 out.name = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:1673, in BlockManager.reduce(self, func)
#    1670 # If 2D, we assume that we're operating column-wise
#    1671 assert self.ndim == 2
# -> 1673 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1674 index = default_index(1)  # placeholder
#    1675 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:13547, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13545     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13546 else:
# > 13547     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/nanops.py:149, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     147         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148 else:
# --> 149     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     151 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/nanops.py:817, in nanmedian(values, axis, skipna, mask)
#     810 warnings.filterwarnings(
#     811     "ignore", "All-NaN slice encountered", RuntimeWarning
#     812 )
#     813 if (values.shape[1] == 1 and axis == 0) or (
#     814     values.shape[0] == 1 and axis == 1
#     815 ):
#     816     # GH52788: fastpath when squeezable, nanmedian for 2D array slow
# --> 817     res = np.nanmedian(np.squeeze(values), keepdims=True)
#     818 else:
#     819     res = np.nanmedian(values, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:1217, in nanmedian(a, axis, out, overwrite_input, keepdims)
#    1214 if a.size == 0:
#    1215     return np.nanmean(a, axis, out=out, keepdims=keepdims)
# -> 1217 return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#    1218                               axis=axis, out=out,
#    1219                               overwrite_input=overwrite_input)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:1085, in _nanmedian(a, axis, out, overwrite_input)
#    1083 part = a.ravel()
#    1084 if out is None:
# -> 1085     return _nanmedian1d(part, overwrite_input)
#    1086 else:
#    1087     out[...] = _nanmedian1d(part, overwrite_input)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:1072, in _nanmedian1d(arr1d, overwrite_input)
#    1067 if arr1d_parsed.size == 0:
#    1068     # Ensure that a nan-esque scalar of the appropriate type (and unit)
#    1069     # is returned for `timedelta64` and `complexfloating`
#    1070     return arr1d[-1]
# -> 1072 return np.median(arr1d_parsed, overwrite_input=overwrite_input)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3927, in median(a, axis, out, overwrite_input, keepdims)
#    3845 @array_function_dispatch(_median_dispatcher)
#    3846 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3847     """
#    3848     Compute the median along the specified axis.
#    3849
#    (...)   3925
#    3926     """
# -> 3927     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#    3928                     overwrite_input=overwrite_input)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/function_base.py:3982, in _median(a, axis, out, overwrite_input)
#    3979 rout = mean(part[indexer], axis=axis, out=out)
#    3980 if supports_nans and sz > 0:
#    3981     # If nans are possible, warn and replace by nans like mean would.
# -> 3982     rout = np.lib.utils._median_nancheck(part, rout, axis)
#    3984 return rout
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/utils.py:1105, in _median_nancheck(data, result, axis)
#    1103     return result
#    1104 potential_nans = data.take(-1, axis=axis)
# -> 1105 n = np.isnan(potential_nans)
#    1106 # masked NaN values are ok, although for masked the copyto may fail for
#    1107 # unmasked ones (this was always broken) when the result is a scalar.
#    1108 if np.ma.isMaskedArray(n):
#
# KeyboardInterrupt:

# %% [markdown]
# # Windos Size of 5s

# %%
window_size = 40 * 5

# %%
for user in dirs:
    print(user)
    ###############################################
    path = os.path.join(folder, user)
    file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    all_dfs = []

    for file in file_names:
        df = pd.read_csv(os.path.join(path, file), sep=" ", header=None)
        df.drop(0, axis=1, inplace=True)
        df.columns = ["X", "Y", "Z"]

        file_dfs = []
        for start in range(0, len(df) - window_size + 1, window_size):
            end = start + window_size
            features = extract_features(df, start, end)
            file_dfs.append(features)

        df_features = pd.concat(file_dfs, ignore_index=True)
        df_features["timestamp"] = file.split(".")[0]
        all_dfs.append(df_features)

    data_ACC = pd.concat(all_dfs, ignore_index=True)
    print(data_ACC.shape)
    ###############################################
    ################################################

    path = os.path.join("./data/audio_naive", user)
    file_names = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    all_features = []
    all_timestamps = []

    for file in file_names:
        file_path = os.path.join(path, file)
        df = pd.read_csv(file_path, header=None)
        df.dropna(axis=1, inplace=True)

        X = df.values  # shape: (n_frames, 13)

        # Statistiques : mean, std, min, max
        stats = [X.mean(axis=0), X.std(axis=0), X.min(axis=0), X.max(axis=0)]
        features = np.concatenate(stats)

        all_features.append(features)
        all_timestamps.append(file.split(".")[0])

    # Création des noms de colonnes
    columns = []
    for stat in ["mean", "std", "min", "max"]:
        columns += [f"mfcc{i}_{stat}" for i in range(X.shape[1])]

    # Création du DataFrame
    data_audio = pd.DataFrame(all_features, columns=columns)
    data_audio["timestamp"] = all_timestamps
    print(data_audio.shape)
    ##############################################################################

    location_path = r"./data/ExtraSensory.per_uuid_absolute_location"
    filename = user + ".absolute_locations.csv.gz"

    full_path = os.path.join(location_path, filename)

    data_loc = pd.read_csv(full_path, compression="gzip")

    print(data_loc.shape)
    ##############################################################################

    location_path = r"./data/ExtraSensory.per_uuid_original_labels"
    filename = user + ".original_labels.csv.gz"
    full_path = os.path.join(location_path, filename)

    data_label = pd.read_csv(full_path, compression="gzip")
    cols_to_drop = [col for col in data_label.columns if "PHONE" in col.upper()]
    data_label = data_label.drop(columns=cols_to_drop)
    data_label.columns = data_label.columns.str.replace(
        "^original_label:", "", regex=True
    )
    data_label.drop("label_source", axis=1, inplace=True)
    print(data_label.shape)

    ####################################################################################
    ####################################################################################
    ####################################FUSION##########################################
    data_merged = pd.merge(data_ACC, data_audio, on="timestamp", how="left")

    data_merged["timestamp"] = data_merged["timestamp"].astype(int)
    data_loc["timestamp"] = data_loc["timestamp"].astype(int)
    data_final = pd.merge(data_merged, data_loc, on="timestamp", how="left")

    data_final_2 = pd.merge(data_final, data_label, on="timestamp", how="left")

    output_folder = "5s"
    os.makedirs(output_folder, exist_ok=True)
    output_path = os.path.join(output_folder, f"{user}__5s.csv")
    
    data_final_2.to_csv(output_path, index=False)
    ##################################################################################
    print("*" * 80)
# Out:
# 00EABED2-271D-49D8-B599-1D4A09240601
# (9148, 67)
# (2228, 53)
# (2287, 3)
# (2287, 105)
# ********************************************************************************
# 098A72A5-E3E5-4F54-A152-BBDA0DF7B694
# (27232, 67)
# (6735, 53)
# (6813, 3)
# (6813, 105)
# ********************************************************************************
# 0A986513-7828-4D53-AA1F-E02D6DF9561B
# (15840, 67)
# (3956, 53)
# (3960, 3)
# (3960, 105)
# ********************************************************************************
# 0BFC35E2-4817-4865-BFA7-764742302A2D
# (12360, 67)
# (3086, 53)
# (3108, 3)
# (3108, 105)
# ********************************************************************************
# 0E6184E1-90C0-48EE-B25A-F1ECB7B9714E
# (30052, 67)
# (7510, 53)
# (7521, 3)
# (7521, 105)
# ********************************************************************************
# 1155FF54-63D3-4AB2-9863-8385D0BD0A13
# (10740, 67)
# (2674, 53)
# (2685, 3)
# (2685, 105)
# ********************************************************************************
# 11B5EC4D-4133-4289-B475-4E737182A406
# (35380, 67)
# (8834, 53)
# (8845, 3)
# (8845, 105)
# ********************************************************************************
# 136562B6-95B2-483D-88DC-065F28409FD2
# (24872, 67)
# (5853, 53)
# (6218, 3)
# (6218, 105)
# ********************************************************************************
# 1538C99F-BA1E-4EFB-A949-6C7C47701B20
# (26196, 67)
# (6470, 53)
# (6549, 3)
# (6549, 105)
# ********************************************************************************
# 1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842
# (29484, 67)
# (7366, 53)
# (7375, 3)
# (7375, 105)
# ********************************************************************************
# 24E40C4C-A349-4F9F-93AB-01D00FB994AF
# (19084, 67)
# (4481, 53)
# (4771, 3)
# (4771, 105)
# ********************************************************************************
# 27E04243-B138-4F40-A164-F40B60165CF3
# (19700, 67)
# (4811, 53)
# (4927, 3)
# (4927, 105)
# ********************************************************************************
# 2C32C23E-E30C-498A-8DD2-0EFB9150A02E
# (34064, 67)
# (8120, 53)
# (8516, 3)
# (8516, 105)
# ********************************************************************************
# 33A85C34-CFE4-4732-9E73-0A7AC861B27A
# (24656, 67)
# (6160, 53)
# (6172, 3)
# (6172, 105)
# ********************************************************************************
# 3600D531-0C55-44A7-AE95-A7A38519464E
# (20812, 67)
# (5131, 53)
# (5203, 3)
# (5203, 105)
# ********************************************************************************
# 40E170A7-607B-4578-AF04-F021C3B0384A
# (30592, 67)
# (7626, 53)
# (7649, 3)
# (7649, 105)
# ********************************************************************************
# 481F4DD2-7689-43B9-A2AA-C8772227162B
# (26760, 67)
# (6679, 53)
# (6691, 3)
# (6691, 105)
# ********************************************************************************
# 4E98F91F-4654-42EF-B908-A3389443F2E7
# (12976, 67)
# (3238, 53)
# (3250, 3)
# (3250, 105)
# ********************************************************************************
# 4FC32141-E888-4BFF-8804-12559A491D8C
# (19916, 67)
# (4883, 53)
# (4979, 3)
# (4979, 105)
# ********************************************************************************
# 5119D0F8-FCA8-4184-A4EB-19421A40DE0D
# (26468, 67)
# (6557, 53)
# (6617, 3)
# (6617, 105)
# ********************************************************************************
# 5152A2DF-FAF3-4BA8-9CA9-E66B32671A53
# (26468, 67)
# (6459, 53)
# (6617, 3)
# (6617, 105)
# ********************************************************************************
# 59818CD2-24D7-4D32-B133-24C2FE3801E5
# (23784, 67)
# (5946, 53)
# (5947, 3)
# (5947, 105)
# ********************************************************************************
# 59EEFAE0-DEB0-4FFF-9250-54D2A03D0CF2
# (30148, 67)
# (7413, 53)
# (7542, 3)
# (7542, 105)
# ********************************************************************************
# 5EF64122-B513-46AE-BCF1-E62AAC285D2C
# (15644, 67)
# (3851, 53)
# (3911, 3)
# (3911, 105)
# ********************************************************************************
# 61359772-D8D8-480D-B623-7C636EAD0C81
# (24288, 67)
# (6071, 53)
# (6079, 3)
# (6079, 105)
# ********************************************************************************
# 61976C24-1C50-4355-9C49-AAE44A7D09F6
# (34920, 67)
# (7696, 53)
# (8730, 3)
# (8730, 105)
# ********************************************************************************
# 665514DE-49DC-421F-8DCB-145D0B2609AD
# (36664, 67)
# (9157, 53)
# (9167, 3)
# (9167, 105)
# ********************************************************************************
# 74B86067-5D4B-43CF-82CF-341B76BEA0F4
# (29068, 67)
# (7267, 53)
# (7298, 3)
# (7298, 105)
# ********************************************************************************
# 78A91A4E-4A51-4065-BDA7-94755F0BB3BB
# (47984, 67)
# (11865, 53)
# (11996, 3)
# (11996, 105)
# ********************************************************************************
# 797D145F-3858-4A7F-A7C2-A4EB721E133C
# (14372, 67)
# (3588, 53)
# (3593, 3)
# (3593, 105)
# ********************************************************************************
# 7CE37510-56D0-4120-A1CF-0E23351428D2
# (39040, 67)
# (9698, 53)
# (9761, 3)
# (9761, 105)
# ********************************************************************************
# 7D9BB102-A612-4E2A-8E22-3159752F55D8
# (6400, 67)
# (1598, 53)
# (1600, 3)
# (1600, 105)
# ********************************************************************************
# 8023FE1A-D3B0-4E2C-A57A-9321B7FC755F
# (36756, 67)
# (9065, 53)
# (9189, 3)
# (9189, 105)
# ********************************************************************************
# 806289BC-AD52-4CC1-806C-0CDB14D65EB6
# (36968, 67)
# (9232, 53)
# (9242, 3)
# (9242, 105)
# ********************************************************************************
# 81536B0A-8DBF-4D8A-AC24-9543E2E4C8E0
# (25372, 67)
# (6253, 53)
# (6407, 3)
# (6407, 105)
# ********************************************************************************
# 83CF687B-7CEC-434B-9FE8-00C3D5799BE6
# (38156, 67)
# (9375, 53)
# (9539, 3)
# (9539, 105)
# ********************************************************************************
# 86A4F379-B305-473D-9D83-FC7D800180EF
# (42864, 67)
# (10699, 53)
# (10738, 3)
# (10738, 105)
# ********************************************************************************
# 96A358A0-FFF2-4239-B93E-C7425B901B47
# (23244, 67)
# (5403, 53)
# (5819, 3)
# (5819, 105)
# ********************************************************************************
# 9759096F-1119-4E19-A0AD-6F16989C7E1C
# (39836, 67)
# (9889, 53)
# (9959, 3)
# (9959, 105)
# ********************************************************************************
# 99B204C0-DD5C-4BB7-83E8-A37281B8D769
# (24112, 67)
# (6025, 53)
# (6038, 3)
# (6038, 105)
# ********************************************************************************
# 9DC38D04-E82E-4F29-AB52-B476535226F2
# (38744, 67)
# (9277, 53)
# (9686, 3)
# (9686, 105)
# ********************************************************************************
# A5A30F76-581E-4757-97A2-957553A2C6AA
# (6668, 67)
# (1666, 53)
# (1667, 3)
# (1667, 105)
# ********************************************************************************
# A5CDF89D-02A2-4EC1-89F8-F534FDABDD96
# (24160, 67)
# (5948, 53)
# (6040, 3)
# (6040, 105)
# ********************************************************************************
# A7599A50-24AE-46A6-8EA6-2576F1011D81
# (15592, 67)
# (3897, 53)
# (3898, 3)
# (3898, 105)
# ********************************************************************************
# A76A5AF5-5A93-4CF2-A16E-62353BB70E8A
# (30080, 67)
# (7417, 53)
# (7520, 3)
# (7520, 105)
# ********************************************************************************
# B09E373F-8A54-44C8-895B-0039390B859F
# (32536, 67)
# (8005, 53)
# (8134, 3)
# (8134, 105)
# ********************************************************************************
# B7F9D634-263E-4A97-87F9-6FFB4DDCB36C
# (37532, 67)
# (9383, 53)
# (9383, 3)
# (9383, 105)
# ********************************************************************************
# B9724848-C7E2-45F4-9B3F-A1F38D864495
# (30504, 67)
# (7483, 53)
# (7626, 3)
# (7626, 105)
# ********************************************************************************
# BE3CA5A6-A561-4BBD-B7C9-5DF6805400FC
# (33236, 67)
# (8254, 53)
# (8309, 3)
# (8309, 105)
# ********************************************************************************
# BEF6C611-50DA-4971-A040-87FB979F3FC1
# (13800, 67)
# (3448, 53)
# (3451, 3)
# (3451, 105)
# ********************************************************************************
# C48CE857-A0DD-4DDB-BEA5-3A25449B2153
# (20364, 67)
# (4984, 53)
# (5092, 3)
# (5092, 105)
# ********************************************************************************
# CA820D43-E5E2-42EF-9798-BE56F776370B
# (31456, 67)
# (7635, 53)
# (7865, 3)
# (7865, 105)
# ********************************************************************************
# CCAF77F0-FABB-4F2F-9E24-D56AD0C5A82F
# (33580, 67)
# (8294, 53)
# (8472, 3)
# (8472, 105)
# ********************************************************************************
# CDA3BBF7-6631-45E8-85BA-EEB416B32A3C
# (11440, 67)
# (2765, 53)
# (2860, 3)
# (2860, 105)
# ********************************************************************************
# CF722AA9-2533-4E51-9FEB-9EAC84EE9AAC
# (14460, 67)
# (3610, 53)
# (3615, 3)
# (3615, 105)
# ********************************************************************************
# D7D20E2E-FC78-405D-B346-DBD3FD8FC92B
# (24840, 67)
# (6034, 53)
# (6210, 3)
# (6210, 105)
# ********************************************************************************
# E65577C1-8D5D-4F70-AF23-B3ADB9D3DBA3
# (13764, 67)
# (3399, 53)
# (3441, 3)
# (3441, 105)
# ********************************************************************************
# ECECC2AB-D32F-4F90-B74C-E12A1C69BBE2
# (14120, 67)
# (92, 53)
# (3530, 3)
# (3530, 105)
# ********************************************************************************
# F50235E0-DD67-4F2A-B00B-1F31ADA998B9
# (9036, 67)
# (2259, 53)
# (2266, 3)
# (2266, 105)
# ********************************************************************************
# FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF
# (19892, 67)
# (4949, 53)
# (4973, 3)
# (4973, 105)
# ********************************************************************************
